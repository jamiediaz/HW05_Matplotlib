# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data
city_data = pd.read_csv(city_data_to_load)
ride_data = pd.read_csv(ride_data_to_load)

# Combine the data into a single dataset
pyber_data = pd.merge(city_data, ride_data, how="left", on=["city", "city"])
# Display the data table for preview
pyber_data.head()
# Out:
#           city  driver_count   type                 date   fare        ride_id
# 0  Richardfort            38  Urban  2018-02-24 08:40:38  13.93  5628545007794
# 1  Richardfort            38  Urban  2018-02-13 12:46:07  14.00   910050116494
# 2  Richardfort            38  Urban  2018-02-16 13:52:19  17.92   820639054416
# 3  Richardfort            38  Urban  2018-02-01 20:18:28  10.26  9554935945413
# 4  Richardfort            38  Urban  2018-04-17 02:26:37  23.00   720020655850

# %%
# Calculate the average fare by city
city_avg_fare = pyber_data.groupby("city")["fare"].mean()

# Calculate the total rides per city
city_total_rides = pyber_data.groupby("city")["ride_id"].count()

# Calculate the total drivers in each city. 
city_total_drivers = pyber_data.groupby("city")["driver_count"].first()

# Get the type for each city
city_type = pyber_data.groupby("city")["type"].first()

# Create the dataframe
pyber_df = pd.DataFrame({"Average Fare":city_avg_fare,
                         "Total Rides":city_total_rides,
                         "Total Drivers":city_total_drivers,
                         "Type":city_type
                       })
# Preview
pyber_df.head()
# Out:
#                Average Fare  Total Rides  Total Drivers      Type
# city
# Amandaburgh       24.641667           18             12     Urban
# Barajasview       25.332273           22             26     Urban
# Barronchester     36.422500           16             11  Suburban
# Bethanyland       32.956111           18             22  Suburban
# Bradshawfurt      40.064000           10              7     Rural

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Group the DF by type
pyber_type_df = pyber_df.groupby("Type")

# Extract allthe urban rows
urban_grp_df = pyber_type_df.get_group("Urban")

# Extract all the suburban rows
suburban_grp_df = pyber_type_df.get_group("Suburban")

# Extract all the rural rows
rural_grp_df = pyber_type_df.get_group("Rural")

# Plot the urban data based on the extracted urban rows
urban_plt = plt.scatter(x=urban_grp_df["Total Rides"], 
                        y=urban_grp_df["Average Fare"], 
                        s=urban_grp_df["Total Drivers"]*10, 
                        color="coral", 
                        edgecolor = "black", 
                        alpha = .5, 
                        label = "Urban" )

# Plot the suburban data based on the extracted suburban rows
suburban_plt = plt.scatter(x=suburban_grp_df["Total Rides"], 
                           y=suburban_grp_df["Average Fare"], 
                           s=suburban_grp_df["Total Drivers"]*10, 
                           color="skyblue", 
                           edgecolor = "black", 
                           alpha = .5, 
                           label = "Suburban")

# Plot the rural data based on the extracted rural rows
rural_plt = plt.scatter(x=rural_grp_df["Total Rides"], 
                        y=rural_grp_df["Average Fare"], 
                        s=rural_grp_df["Total Drivers"]*10, 
                        color="gold", 
                        edgecolor = "black", 
                        alpha = .5, 
                        label = "Rural")

# Create a legend
# Use legendHandles[] to make the markers in the legend unitform in size. 
lgnd = plt.legend(loc="best", scatterpoints=1, fontsize=10)
lgnd.legendHandles[0]._sizes = [30]
lgnd.legendHandles[1]._sizes = [30]
lgnd.legendHandles[2]._sizes = [30]


# Label the graph
plt.title("Pyber Ride Sharing Data (2016)")
plt.xlabel("Total Number of Rides (Per City)")
plt.ylabel("Average Fare ($)")
plt.figtext(x=1, y=.5, s="Note:\nCircle size correlates with driver count per city.")

# Enable the grid and give it a tight layout.  
plt.grid()
plt.tight_layout()

# Save the figure with external text
plt.savefig("../Images/pyber_plot.png", bbox_inches = "tight")

plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate the sum of the fares in the pyber_data dataframe
fare_total = pyber_data["fare"].sum()

# Calculate the sum of the fares in the pyber_data dataframe for each city type
fare_type_total = pyber_data.groupby("type")["fare"].sum()

# Calculate the percentage
fare_type_prcnt = round((fare_type_total/fare_total)*100,2)


# Labels for the sections of our pie chart
labels = ["Rural", "Suburban", "Urban"]

# The values of each section of the pie chart
sizes = [fare_type_prcnt["Rural"], fare_type_prcnt["Suburban"], fare_type_prcnt["Urban"]]

# Colors for the sections in the pie chart
colors = ["gold", "skyblue", "coral"]

# Separate the Urban slice
explode = (0, 0, 0.1)

# Build Pie Chart
plt.pie(sizes, 
        explode=explode, 
        labels=labels, 
        colors=colors, 
        autopct="%1.1f%%", 
        shadow=True, 
        startangle=150)

# Add a title
plt.title("% of Total Fares by City Type")

# Give the chart a slight tilt and tighten the layout
plt.axis("normal")
plt.tight_layout()

# Save the figure.
plt.savefig("../Images/fares_pie.png", bbox_inches = "tight")

plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Get the sum of all the rides from the pyber_df dataframe
ride_total = pyber_df["Total Rides"].sum()

# Get a sum of all the rides from the pyber_df dataframe and sort them by city type
ride_type_total = pyber_df.groupby("Type")["Total Rides"].sum()

#calculate the percentage
ride_type_prcnt = round((ride_type_total/ride_total)*100,2)


# Labels for the sections of our pie chart
labels = ["Rural", "Suburban", "Urban"]

# The values of each section of the pie chart
sizes = [ride_type_prcnt["Rural"], ride_type_prcnt["Suburban"], ride_type_prcnt["Urban"]]

# The colors for each slice
colors = ["gold", "skyblue", "coral"]

# Separate the Urban slice
explode = (0, 0, 0.1)

# Build Pie Chart
plt.pie(sizes, 
        explode=explode, 
        labels=labels, 
        colors=colors, 
        autopct="%1.1f%%", 
        shadow=True, 
        startangle=150)

# Give it a title
plt.title("% of Total Rides by City Type")

# Give the chart a slight tilt back, and tighten the layout. 
plt.axis("normal")
plt.tight_layout()

#save the image
plt.savefig("../Images/rides_pie.png", bbox_inches = "tight")

plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate the sum of all the drivers.
drive_total = pyber_df["Total Drivers"].sum()

#Calculate the sum of all the drivers in each city type
drive_type_total = pyber_df.groupby("Type")["Total Drivers"].sum()

#Calculate the percentage of the drivers in each city type
drive_type_prcnt = round((drive_type_total/drive_total)*100,2)

# Labels for the sections of our pie chart
labels = ["Rural", "Suburban", "Urban"]

# The values of each section of the pie chart
sizes = [drive_type_prcnt["Rural"], drive_type_prcnt["Suburban"], drive_type_prcnt["Urban"]]

# Colors for the pie chart
colors = ["gold", "skyblue", "coral"]

# Separate the urban slice
explode = (0, 0, 0.1)

# Build Pie Chart
plt.pie(sizes, 
        explode=explode, 
        labels=labels, 
        colors=colors, 
        autopct="%1.1f%%", 
        shadow=True, 
        startangle=150)

# Create a title
plt.title("% of Total Drivers by City Type")

# Give the chart a slight tilt to the back  and give it a tight layout
plt.axis("normal")
plt.tight_layout()

#save the figure. 
plt.savefig("../Images/drivers_pie.png", bbox_inches = "tight")

plt.show()
